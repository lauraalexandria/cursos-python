# %% [markdown]
# # Seaborn

# %% [markdown]
# #### Importando bibliotecas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("https://raw.githubusercontent.com/lauraalexandria/cursos_python/main/data/seattle_weather.csv")

# %% [markdown]
# #### Gráficos de Pontos

# %%
sns.scatterplot(data = df, x = "MLY-TAVG-NORMAL", y = "MLY-PRCP-NORMAL") 
plt.show()

# %%
sns.scatterplot(data = df, x = "MLY-TAVG-NORMAL", y = "MLY-PRCP-NORMAL", hue = "MLY-PRCP-NORMAL") # Legenda com as cores pela categórica;
# hue_order ainda ajuda a ordenar na legenda e dá pra definir em palette = {"Yes": "red", "No": "black"}
plt.show()

# %%
sns.relplot(data = df, x = "MLY-TAVG-NORMAL", y = "MLY-PRCP-NORMAL", kind = "scatter", col = "DATE") 
# Vários gráficos de pontos pelas classes da categoria, um do lado do outro
plt.show()

# %%
sns.relplot(data = df, x = "MLY-TAVG-NORMAL", y = "MLY-PRCP-NORMAL", kind = "scatter", row = "DATE") 
# Versão dos gráficos em uma única linha;
plt.show()

# %%
sns.relplot(data = df, x = "MLY-TAVG-NORMAL", y = "MLY-PRCP-NORMAL", kind = "scatter", col = "DATE", col_wrap = 6) 
plt.show()

# %%
iris = sns.load_dataset("iris")
iris_long = pd.melt(iris, "species", var_name="measurement")
g = sns.FacetGrid(iris_long, hue="species", col="measurement", col_wrap=2, sharex=False)
g.map(plt.hist, "value", alpha=.4)

# %%
sns.scatterplot(data = df, x = "MLY-TAVG-NORMAL", y = "MLY-PRCP-NORMAL", size = "DATE") # Permite que os pontos mudem de tamanho;
plt.show()

# %%
sns.scatterplot(data = df, x = "MLY-TAVG-NORMAL", y = "MLY-PRCP-NORMAL", style = "DATE") # Permite que os pontos mudem de formato;
plt.show()

# %%
sns.scatterplot(data = df, x = "MLY-TAVG-NORMAL", y = "MLY-PRCP-NORMAL", alpha = 0.2) 
# Altera a opacidade dos pontos, o que pode ser interessante quando é sobreposição (alpha recebe valores entre 0 a 1); 
plt.show()

# %%
sns.stripplot(data=df, x='DATE', y='MLY-TAVG-NORMAL', jitter=True)
# Quando uma das variáveis é categórica;
plt.show()

# %% [markdown]
# #### Gráficos de linhas

# %%
sns.relplot(data = df, x = "DATE", y = "MLY-PRCP-NORMAL", kind = "line")
# Se houverem diferentes observação para os valores de x, automaticamente temos um intervalo de confiança para a linha;
plt.show()

# %%
sns.relplot( data = df, x = "MLY-TAVG-NORMAL", y = "MLY-PRCP-NORMAL", kind = "line", style = "DATE", hue = "DATE", 
            markers = True, dashes = False ) # Linhas de acordo com as categorias, mostra os pontos também e sem grades;
plt.show()

# %%
sns.relplot(data = df, x = "DATE", y = "MLY-PRCP-NORMAL", kind = "line", ci = "sd")
# O intervalo de confiança é realizado com o desvio padrão;
plt.show()

# %%
sns.relplot(data = df, x = "DATE", y = "MLY-PRCP-NORMAL", kind = "line", ci = None)
# Retira  o intervalo de confiança;
plt.show()

# %%
sns.catplot(x = "DATE", y = "MLY-PRCP-NORMAL", data = df, kind = "point") # Gráfico de linhas para variáveis categóricas!
plt.show()

# %%
sns.catplot(x = "DATE", y = "MLY-PRCP-NORMAL", data = df, kind = "point", hue = "NAME") # Para ir separando as linhas
plt.show()

# %%
sns.catplot(x = "DATE", y = "MLY-PRCP-NORMAL", data = df, kind = "point", hue = "NAME", join = False) # Fica só os pontos
plt.show()

# %% [markdown]
# #### Gráficos de barras

# %%
sns.countplot(data = df, x = "DATE") # Gráfico de Barras de frequência;
plt.show()

# %%
sns.countplot(y = df["DATE"]) # Barras horizontais;
plt.show()

# %%
sns.catplot(data = df, x = "DATE", kind = "count") # Com outra função, que tem args muito parecidos com o relplot!
plt.show()

# %%
# sns.catplot(x = "categórica", data = df, kind = "count",
#             order = ["cat1", "cat2", ...]) # Ordenando o as barras;
# plt.show()

# %%
cross_tab_prop = pd.crosstab(columns=df["DATE"],
                             index=df["NAME"],
                             normalize="index")#.sort_values("COluna para ordenar as barras")
cross_tab_prop.plot.barh(stacked=True, figsize=(12, 5))
# Out:
# <AxesSubplot:ylabel='NAME'>

# %%
sns.catplot(x = "DATE", y = "MLY-PRCP-NORMAL", data = df, kind = "bar") # Barras com a média da variável pelas categorias, com um intervalo;
plt.show()

# %% [markdown]
# #### Boxplot

# %%
sns.catplot(x = "DATE", y = "MLY-PRCP-NORMAL", data = df, kind = "box") 
plt.show()

# %%
sns.catplot(x = "DATE", y = "MLY-PRCP-NORMAL", data = df, kind = "box", sym = "") # não mostra os outlier
plt.show()

# %%
sns.catplot(x = "DATE", y = "MLY-PRCP-NORMAL", data = df, kind = "box", whis = 2.0) # muda a extensão das retas 
plt.show()

# %%
sns.catplot(x = "DATE", y = "MLY-PRCP-NORMAL", data = df, kind = "box", whis = [2, 95]) # muda a extensão das retas - em % 
plt.show()

# %%
sns.boxplot(data=df, x= 'DATE', y= 'MLY-PRCP-NORMAL') # Outra fórmula;
plt.show()

# %% [markdown]
# #### Gráfico de Distribuição

# %%
sns.distplot(df['MLY-PRCP-NORMAL'], rug=True, kde_kws={'shade':True})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['MLY-PRCP-NORMAL'], hist=False, rug=True, kde_kws={'shade':True})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Regressão

# %%
sns.regplot(x = "MLY-PRCP-NORMAL", y = "MLY-TAVG-NORMAL", data = df) 
plt.show()

# %%
sns.lmplot(data=df, x = "MLY-PRCP-NORMAL", y = "MLY-TAVG-NORMAL", col = "DATE", col_wrap = 6)   # Também é possível separar por classes...
plt.show()

# %%
sns.regplot(x = "MLY-PRCP-NORMAL", y = "MLY-TAVG-NORMAL", data = df, order = 2) # Alterando o grau do polinômio 
plt.show()

# %%
sns.residplot(x = "MLY-PRCP-NORMAL", y = "MLY-TAVG-NORMAL", data = df, color = "g") # Análise de Resíduos
plt.show()

# %% [markdown]
# #### Customização dos Gráficos

# %% [markdown]
# ##### Estilos

# %%
sns.set_style("dark") # ou "ticks" ou "whitegrid"

sns.regplot(x = "MLY-PRCP-NORMAL", y = "MLY-TAVG-NORMAL", data = df) 
plt.show()

# %%
sns.set_palette("RdBu") # ou "PRGn", "RdBu_r", "PRGn_r", "Greys", "Blues", "PuRd", "GnBu", "Purples" ...

sns.regplot(x = "MLY-PRCP-NORMAL", y = "MLY-TAVG-NORMAL", data = df) 
plt.show()

# %% [markdown]
# ##### Títulos

# %% [markdown]
# #### Matriz de Correlação

# %%
df = pd.DataFrame({"Day 1": [7,1,5,6,3,10,5,8],
                    "Day 2" : [1,2,8,4,3,9,5,2],
                    "Day 3" : [4,6,5,8,6,1,2,3],
                    "Day 4" : [5,8,9,5,1,7,8,9]})

sns.heatmap(df.corr(), vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>
